# %%
# !git clone https://github.com/ashawkey/stable-dreamfusion.git
# Out:
# Cloning into 'stable-dreamfusion'...

# %%
cd stable-dreamfusion
# Out:
# C:\Users\saura\stable-dreamfusion

# %%
# !pip install -r requirements.txt
# Out:
# ...
#   Cloning https://github.com/NVlabs/nvdiffrast/ to c:\users\saura\appdata\local\temp\pip-req-build-ki5n8btf
#   Resolved https://github.com/NVlabs/nvdiffrast/ to commit 729261dc64c4241ea36efda84fbf532cc8b425b8
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Cloning https://github.com/openai/CLIP.git to c:\users\saura\appdata\local\temp\pip-req-build-pet0x3fo
#   Resolved https://github.com/openai/CLIP.git to commit dcba3cb2e2827b402d2701e7e1c7d9fed8a20ef1
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running command git clone --filter=blob:none --quiet https://github.com/NVlabs/nvdiffrast/ 'C:\Users\saura\AppData\Local\Temp\pip-req-build-ki5n8btf'
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/CLIP.git 'C:\Users\saura\AppData\Local\Temp\pip-req-build-pet0x3fo'

# %%
# !pip list
# Out:
# Package                     Version
# --------------------------- -------------
# absl-py                     2.1.0
# accelerate                  1.0.1
# aiofiles                    24.1.0
# aiohappyeyeballs            2.4.3
# aiohttp                     3.10.10
# aiosignal                   1.3.1
# annotated-types             0.7.0
# antlr4-python3-runtime      4.9.3
# anyio                       4.2.0
# argon2-cffi                 21.3.0
# argon2-cffi-bindings        21.2.0
# asttokens                   2.0.5
# async-lru                   2.0.4
# async-timeout               4.0.3
# attrs                       24.2.0
# Babel                       2.11.0
# backcall                    0.2.0
# beautifulsoup4              4.12.3
# bleach                      4.1.0
# Brotli                      1.0.9
# carvekit_colab              4.1.2
# certifi                     2024.8.30
# cffi                        1.17.1
# charset-normalizer          3.3.2
# click                       8.1.7
# ...

# %%
# !pip install --upgrade torch torchvision torchaudio ninja
# !pip install cmake
# Out:
# ...
#    ---------------------------------------- 0.0/35.6 MB ? eta -:--:--
#    ----------- ---------------------------- 10.2/35.6 MB 58.3 MB/s eta 0:00:01
#    ---------------------------------- ----- 30.4/35.6 MB 80.4 MB/s eta 0:00:01
#    ---------------------------------------- 35.6/35.6 MB 78.1 MB/s eta 0:00:00
# ...

# %%
# !pip install --upgrade torch torchvision torchaudio ninja
# !pip install cmake

# %%
# !pip install .
# Out:
# Processing c:\users\saura\stable-dreamfusion\raymarching
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Running setup.py clean for raymarching
# Failed to build raymarching
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [85 lines of output]
#   running bdist_wheel
#   running build
#   running build_ext
#   building '_raymarching' extension
#   creating C:\Users\saura\stable-dreamfusion\raymarching\build\temp.win-amd64-cpython-39\Release\Users\saura\stable-dreamfusion\raymarching\src
#   Emitting ninja build file C:\Users\saura\stable-dreamfusion\raymarching\build\temp.win-amd64-cpython-39\Release\build.ninja...
#   Compiling objects...
#   Allowing ninja to set a default number of workers... (overridable by setting the environment variable MAX_JOBS=N)
# ...

# %%
cd C:\Users\saura\stable-dreamfusion\raymarching
# Out:
# C:\Users\saura\stable-dreamfusion\raymarching

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# building '_raymarching' extension
# creating C:\Users\saura\stable-dreamfusion\raymarching\build\temp.win-amd64-cpython-39\Release\Users\saura\stable-dreamfusion\raymarching\src
# ...

# %%
# !python main.py -O2 --text "hamburger" --workspace "trial1" --iters 3000 --lr 1e-3 --w 64 --h 64 --seed 0 --lambda_entropy 1e-4 --ckpt "latest" --save_mesh --num_steps 64 --upsample_steps 32
# Out:
# Namespace(file=None, text='hamburger', negative='', O=False, O2=True, test=False, six_views=False, eval_interval=1, test_interval=100, workspace='trial1', seed='0', image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=True, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=3000, lr=0.001, ckpt='latest', cuda_ray=False, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=4096, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='vanilla', optim='adan', sd_version='2.1', hf_
# ...

# %%
# !python main.py -O2 --test --workspace "trial1" --save_mesh --max_ray_batch 1024
# Out:
# Namespace(file=None, text=None, negative='', O=False, O2=True, test=True, six_views=False, eval_interval=1, test_interval=100, workspace='trial1', seed=None, image=None, image_config=None, known_view_interval=4, IF=False, guidance=['SD'], guidance_scale=100, save_mesh=True, mcubes_resolution=256, decimate_target=50000.0, dmtet=False, tet_grid_size=128, init_with='', lock_geo=False, perpneg=False, negative_w=-2, front_decay_factor=2, side_decay_factor=10, iters=10000, lr=0.001, ckpt='latest', cuda_ray=False, taichi_ray=False, max_steps=1024, num_steps=64, upsample_steps=32, update_extra_interval=16, max_ray_batch=1024, latent_iter_ratio=0.2, albedo_iter_ratio=0, min_ambient_ratio=0.1, textureless_ratio=0.2, jitter_pose=False, jitter_center=0.2, jitter_target=0.2, jitter_up=0.02, uniform_sphere_rate=0, grad_clip=-1, grad_clip_rgb=-1, bg_radius=1.4, density_activation='exp', density_thresh=10, blob_density=5, blob_radius=0.2, backbone='vanilla', optim='adan', sd_version='2.1', hf_key=No
# ...

# %%
import os
import glob
from IPython.display import HTML
from base64 import b64encode

def get_latest_file(path):
  dir_list = glob.glob(path)
  dir_list.sort(key=lambda x: os.path.getmtime(x))
  return dir_list[-1]

def show_video(video_path, video_width = 600):
   
  video_file = open(video_path, "r+b").read()
  video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"

  return HTML(f"""<video width={video_width} controls><source src="{video_url}"></video>""")

Workspace="C:\\Users\\saura\\stable-dreamfusion\\trial1"
rgb_video = get_latest_file(os.path.join(Workspace, 'results', '*_rgb.mp4'))
show_video(rgb_video)
# Out:
# <video width=600 controls><source src="data:video/mp4;base64,..."></video>
